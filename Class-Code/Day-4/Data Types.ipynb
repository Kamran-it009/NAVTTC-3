# %%
name = 'Muhammad Kamran Khan'
print(name)
# Out:
# Muhammad Kamran Khan

# %%
name[9] # indexing
# Out:
# 'K'

# %%
name[-4] # Negative Indexing
# Out:
# 'K'

# %%
name[9: 15] # Slicing
# Out:
# 'Kamran'

# %%
name[9: 15: 2]
# Out:
# 'Kma'

# %%
name[:3]
# Out:
# 'Muh'

# %%
name[2:]
# Out:
# 'hammad Kamran Khan'

# %%
name[:]
# Out:
# 'Muhammad Kamran Khan'

# %%
name[::2]
# Out:
# 'Mhma arnKa'

# %%
len(name)
# Out:
# 20

# %%
name.upper()
# Out:
# 'MUHAMMAD KAMRAN KHAN'

# %%
name
# Out:
# 'Muhammad Kamran Khan'

# %%
name.lower()
# Out:
# 'muhammad kamran khan'

# %%
name.split('K')
# Out:
# ['Muhammad ', 'amran ', 'han']

# %%
words = name.split(' ')

# %%
words
# Out:
# ['Muhammad', 'Kamran', 'Khan']

# %%
'-'.join(words)
# Out:
# 'Muhammad-Kamran-Khan'

# %%
name2 = 'My name is Kamran. Kamran is not a good boy.'

# %%
name2.find('Kamran')
# Out:
# 11

# %%
name.replace('Khan', 'Engineer')
# Out:
# 'Muhammad Kamran Engineer'

# %%
name
# Out:
# 'Muhammad Kamran Khan'

# %%
name[::-1]
# Out:
# 'nahK narmaK dammahuM'

# %%
str1 = "apple"
str2 = "banana"
str1 == str2
# Out:
# False

# %%
str1 > str2
# Out:
# False

# %%
str1 = "lemon"
str2 = "apple"
str1 > str2
# Out:
# True

# %%
numbers = [10, 34, 45, 56]

# %%
numbers
# Out:
# [10, 34, 45, 56]

# %%
fruits = ['apple', 'banana', 'cherry', 'mango', 'orange', 'almod', 'melon']
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'orange', 'almod', 'melon']

# %%
fruits[-2: -5]
# Out:
# []

# %%
fruits[-2: 4]
# Out:
# []

# %%
fruits[2: -2]
# Out:
# ['cherry', 'mango', 'orange']

# %%
fruits[-2] = 'almond'

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'orange', 'almond', 'melon']

# %%
fruits[2] = 'grapes'

# %%
fruits
# Out:
# ['apple', 'banana', 'grapes', 'mango', 'orange', 'almond', 'melon']

# %%
fruits[1: 3] = ['watermelon', 'peach']

# %%
fruits
# Out:
# ['apple', 'watermelon', 'peach', 'mango', 'orange', 'almond', 'melon']

# %%
fruits[2: 4] = ['banana']

# %%
fruits
# Out:
# ['apple', 'watermelon', 'banana', 'orange', 'almond', 'melon']

# %%
fruits[2] = ['stawberry', 'cherry']

# %%
fruits
# Out:
# ['apple', 'watermelon', ['stawberry', 'cherry'], 'orange', 'almond', 'melon']

# %%
fruits = ['apple', 'banana', 'cherry', 'mango', 'orange', 'almond', 'melon']
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'orange', 'almond', 'melon']

# %%
fruits.insert(1, 'grapes')

# %%
fruits
# Out:
# ['apple', 'grapes', 'banana', 'cherry', 'mango', 'orange', 'almond', 'melon']

# %%
fruits.append('lemon')

# %%
fruits
# Out:
# ['apple',
#  'grapes',
#  'banana',
#  'cherry',
#  'mango',
#  'orange',
#  'almond',
#  'melon',
#  'lemon']

# %%
fruits.remove('mango')

# %%
fruits2 = ['apple', 'grapes', 'banana', 'cherry', 'orange', 'melon', 'melon', 'lemon']

# %%
fruits2.remove('melon')

# %%
fruits2
# Out:
# ['apple', 'grapes', 'banana', 'cherry', 'orange', 'melon', 'lemon']

# %%
fruits2.pop(-2)
# Out:
# 'melon'

# %%
deleted_item = fruits2.pop(1)

# %%
fruits2
# Out:
# ['apple', 'banana', 'cherry', 'orange', 'lemon']

# %%
fruits2.append(deleted_item)

# %%
fruits2
# Out:
# ['apple', 'banana', 'cherry', 'orange', 'lemon', 'grapes']

# %%
fruits = ['guava', 'Stawberry', 'almond', 'apple', 'grapes']

# %%
fruits.sort()

# %%
fruits
# Out:
# ['Stawberry', 'almond', 'apple', 'grapes', 'guava']

# %%
fruits.sort(reverse = True)

# %%
fruits
# Out:
# ['guava', 'grapes', 'apple', 'almond', 'Stawberry']

# %%
fruits.reverse()

# %%
fruits
# Out:
# ['Stawberry', 'almond', 'apple', 'grapes', 'guava']
